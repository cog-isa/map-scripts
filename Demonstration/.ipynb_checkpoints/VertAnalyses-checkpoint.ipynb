# %% [markdown]
# # Analyses Of Vertices

# %%
name_table = 'simple_auto_table.pickle'
from ScriptExtract.Preprocessing.TextProcessing import table
from ScriptExtract.GraphScript import graph_construction as GrConstr

path = "../Texts/"
list_files = [path + 'text0_0.txt']
script_ = GrConstr.get_srcipt(list_files, name_table)

# %%
V_descr = script_.V_descr

# %%
for v in script_.V:
    print('Num Vert:', v)
    GrConstr.print_dict(V_descr[v])
    print('\n' + '='*100)
# Out:
# Num Vert: (-1, -1)
#
# ====================================================================================================
# Num Vert: (0, 9)
# К покупке автомобиля я подходил САЙТ я рассмотрел варианты покупки бюджетного автомобиля .
#
# ====================================================================================================
# Num Vert: (0, 38)
# Я разобрал варианты покупкикак БУ автомобиля , так и нового .
#
# ОБЪЕКТ
# вариант (варианты покупкикак БУ автомобиля) - разбирать (разобрал)
#
# СУБЪЕКТ
# я (Я) - разбирать (разобрал)
#
# ====================================================================================================
# Num Vert: (0, 45)
# После подсчета имеющихся средств , я рассмотрел варианты егопокупки по госпрограмме и в кредит .
#
# ОБЪЕКТ
# вариант (варианты покупкикак БУ автомобиля) - разбирать (разобрал)
#
# СУБЪЕКТ
# я (Я) - разбирать (разобрал)
# я (я) - рассматривать (рассмотрел)
#
# ====================================================================================================
# Num Vert: (0, 28)
# Наиболее приемлемым мне показался вариант SkodaRapidс САЙТ турбированным двигателем .
#
# ОБЪЕКТ
# вариант (варианты покупкикак БУ автомобиля) - разбирать (разобрал)
# вариант (вариант SkodaRapidс САЙТ двигателем) - показываться (показался)
#
# СУБЪЕКТ
# я (Я) - разбирать (разобрал)
# я (я) - рассматривать (рассмотрел)
#
# ====================================================================================================
# Num Vert: (0, 16)
# Япроверил рынок автомобилей , подходящих по этому параметру .
#
# ОБЪЕКТ
# вариант (варианты покупкикак БУ автомобиля) - разбирать (разобрал)
# вариант (вариант SkodaRapidс САЙТ двигателем) - показываться (показался)
#
# СУБЪЕКТ
# я (Я) - разбирать (разобрал)
# я (я) - рассматривать (рассмотрел)
#
# ====================================================================================================
# Num Vert: (0, 26)
# Я рассматривал следующие параметры : мощность двигателя , объем и удобство салона , наличие полезных функций , внешний вид авто .
#
# ОБЪЕКТ
# вариант (варианты покупкикак БУ автомобиля) - разбирать (разобрал)
# вариант (вариант SkodaRapidс САЙТ двигателем) - показываться (показался)
# параметр (следующие параметры мощность двигателя объем и удобство салона наличие полезных функций внешний вид авто) - рассматривать (рассматривал)
#
# СУБЪЕКТ
# я (Я) - разбирать (разобрал)
# я (я) - рассматривать (рассмотрел)
#
# ====================================================================================================
# Num Vert: (0, 89)
# Вотделении я поставил автомобиль на учет .
#
# ОБЪЕКТ
# вариант (варианты покупкикак БУ автомобиля) - разбирать (разобрал)
# вариант (вариант SkodaRapidс САЙТ двигателем) - показываться (показался)
# параметр (следующие параметры мощность двигателя объем и удобство салона наличие полезных функций внешний вид авто) - рассматривать (рассматривал)
# автомобиль (автомобиль на учет) - поставлять (поставил)
#
# СУБЪЕКТ
# я (Я) - разбирать (разобрал)
# я (я) - рассматривать (рассмотрел)
# я (я) - поставлять (поставил)
#
# ====================================================================================================
# Num Vert: (0, 87)
# После приобретенияавтомобиля , в течение недели , я перевез автомобиль до отделения ГИБДД .
#
# ОБЪЕКТ
# вариант (варианты покупкикак БУ автомобиля) - разбирать (разобрал)
# вариант (вариант SkodaRapidс САЙТ двигателем) - показываться (показался)
# параметр (следующие параметры мощность двигателя объем и удобство салона наличие полезных функций внешний вид авто) - рассматривать (рассматривал)
# автомобиль (автомобиль на учет) - поставлять (поставил)
# автомобиль (автомобиль) - перевозить (перевез)
#
# СУБЪЕКТ
# я (Я) - разбирать (разобрал)
# я (я) - рассматривать (рассмотрел)
# я (я) - поставлять (поставил)
#
# ====================================================================================================
# Num Vert: (0, 42)
# Всалоне Volkswagen мне понравился автомобиль Tiguan по причине его хорошиххарактеристик и массы отличных отзывов владельцев .
#
# ОБЪЕКТ
# вариант (варианты покупкикак БУ автомобиля) - разбирать (разобрал)
# вариант (вариант SkodaRapidс САЙТ двигателем) - показываться (показался)
# параметр (следующие параметры мощность двигателя объем и удобство салона наличие полезных функций внешний вид авто) - рассматривать (рассматривал)
# автомобиль (автомобиль на учет) - поставлять (поставил)
# автомобиль (автомобиль) - перевозить (перевез)
# автомобиль (автомобиль Tiguan по причине его хорошиххарактеристик и массы отличных отзывов владельцев) - понравиться (понравился)
#
# СУБЪЕКТ
# я (Я) - разбирать (разобрал)
# я (я) - рассматривать (рассмотрел)
# я (я) - поставлять (поставил)
# я (мне) - понравиться (понравился)
#
# ====================================================================================================
# Num Vert: (0, 23)
# Я пришел к выводу , чтосреди этих автомобилей мне ни один не подходит .
#
# ОБЪЕКТ
# вариант (варианты покупкикак БУ автомобиля) - разбирать (разобрал)
# вариант (вариант SkodaRapidс САЙТ двигателем) - показываться (показался)
# параметр (следующие параметры мощность двигателя объем и удобство салона наличие полезных функций внешний вид авто) - рассматривать (рассматривал)
# автомобиль (автомобиль на учет) - поставлять (поставил)
# автомобиль (автомобиль) - перевозить (перевез)
# автомобиль (автомобиль Tiguan по причине его хорошиххарактеристик и массы отличных отзывов владельцев) - понравиться (понравился)
#
# СУБЪЕКТ
# я (Я) - разбирать (разобрал)
# я (я) - рассматривать (рассмотрел)
# я (я) - поставлять (поставил)
# я (мне) - понравиться (понравился)
# автомобиль (чтосреди этих автомобилей) - подходить (подходит не)
#
# ====================================================================================================
# Num Vert: (0, 80)
# Далее , я переместился в салон Volkswagen и совершил сделку попокупке автомобиля .
#
# ОБЪЕКТ
# вариант (варианты покупкикак БУ автомобиля) - разбирать (разобрал)
# вариант (вариант SkodaRapidс САЙТ двигателем) - показываться (показался)
# параметр (следующие параметры мощность двигателя объем и удобство салона наличие полезных функций внешний вид авто) - рассматривать (рассматривал)
# автомобиль (автомобиль на учет) - поставлять (поставил)
# автомобиль (автомобиль) - перевозить (перевез)
# автомобиль (автомобиль Tiguan по причине его хорошиххарактеристик и массы отличных отзывов владельцев) - понравиться (понравился)
#
# СУБЪЕКТ
# я (Я) - разбирать (разобрал)
# я (я) - рассматривать (рассмотрел)
# я (я) - поставлять (поставил)
# я (мне) - понравиться (понравился)
# автомобиль (чтосреди этих автомобилей) - подходить (подходит не)
# я (я) - перемещаться (переместился)
#
# ====================================================================================================
# Num Vert: (0, 58)
# В каждом салоне я заставлял делать мне коммерческоепредложение .
#
# ЛОКАТИВ:
# салон (В каждом салоне)
#
# ОБЪЕКТ
# вариант (варианты покупкикак БУ автомобиля) - разбирать (разобрал)
# вариант (вариант SkodaRapidс САЙТ двигателем) - показываться (показался)
# параметр (следующие параметры мощность двигателя объем и удобство салона наличие полезных функций внешний вид авто) - рассматривать (рассматривал)
# автомобиль (автомобиль на учет) - поставлять (поставил)
# автомобиль (автомобиль) - перевозить (перевез)
# автомобиль (автомобиль Tiguan по причине его хорошиххарактеристик и массы отличных отзывов владельцев) - понравиться (понравился)
#
# СУБЪЕКТ
# я (Я) - разбирать (разобрал)
# я (я) - рассматривать (рассмотрел)
# я (я) - поставлять (поставил)
# я (мне) - понравиться (понравился)
# автомобиль (чтосреди этих автомобилей) - подходить (подходит не)
# я (я) - перемещаться (переместился)
# я (я) - заставлять (заставлял)
#
# ====================================================================================================
# Num Vert: (0, 33)
# После этого я проверил вариантпокупки автомобиля у банка .
#
# ЛОКАТИВ:
# банк (у банка)
#
# ОБЪЕКТ
# вариант (варианты покупкикак БУ автомобиля) - разбирать (разобрал)
# вариант (вариант SkodaRapidс САЙТ двигателем) - показываться (показался)
# параметр (следующие параметры мощность двигателя объем и удобство салона наличие полезных функций внешний вид авто) - рассматривать (рассматривал)
# автомобиль (автомобиль на учет) - поставлять (поставил)
# автомобиль (автомобиль) - перевозить (перевез)
# автомобиль (автомобиль Tiguan по причине его хорошиххарактеристик и массы отличных отзывов владельцев) - понравиться (понравился)
# вариантпокупка (вариантпокупки автомобиля) - проверять (проверил)
#
# СУБЪЕКТ
# я (Я) - разбирать (разобрал)
# я (я) - рассматривать (рассмотрел)
# я (я) - поставлять (поставил)
# я (мне) - понравиться (понравился)
# автомобиль (чтосреди этих автомобилей) - подходить (подходит не)
# я (я) - перемещаться (переместился)
# я (я) - заставлять (заставлял)
# я (я) - проверять (проверил)
#
# ====================================================================================================
# Num Vert: (0, 70)
# Для разового снятия денег я позвонил в банк Tinkof .
#
# ЛОКАТИВ:
# банк (у банка)
#
# ОБЪЕКТ
# вариант (варианты покупкикак БУ автомобиля) - разбирать (разобрал)
# вариант (вариант SkodaRapidс САЙТ двигателем) - показываться (показался)
# параметр (следующие параметры мощность двигателя объем и удобство салона наличие полезных функций внешний вид авто) - рассматривать (рассматривал)
# автомобиль (автомобиль на учет) - поставлять (поставил)
# автомобиль (автомобиль) - перевозить (перевез)
# автомобиль (автомобиль Tiguan по причине его хорошиххарактеристик и массы отличных отзывов владельцев) - понравиться (понравился)
# вариантпокупка (вариантпокупки автомобиля) - проверять (проверил)
#
# СУБЪЕКТ
# я (Я) - разбирать (разобрал)
# я (я) - рассматривать (рассмотрел)
# я (я) - поставлять (поставил)
# я (мне) - понравиться (понравился)
# автомобиль (чтосреди этих автомобилей) - подходить (подходит не)
# я (я) - перемещаться (переместился)
# я (я) - заставлять (заставлял)
# я (я) - проверять (проверил)
# я (я) - позвонить (позвонил)
#
# ====================================================================================================
# Num Vert: (-2, -2)
#
#
# ЛОКАТИВ:
# банк (у банка)
#
# ОБЪЕКТ
# вариант (варианты покупкикак БУ автомобиля) - разбирать (разобрал)
# вариант (вариант SkodaRapidс САЙТ двигателем) - показываться (показался)
# параметр (следующие параметры мощность двигателя объем и удобство салона наличие полезных функций внешний вид авто) - рассматривать (рассматривал)
# автомобиль (автомобиль на учет) - поставлять (поставил)
# автомобиль (автомобиль) - перевозить (перевез)
# автомобиль (автомобиль Tiguan по причине его хорошиххарактеристик и массы отличных отзывов владельцев) - понравиться (понравился)
# вариантпокупка (вариантпокупки автомобиля) - проверять (проверил)
#
# СУБЪЕКТ
# я (Я) - разбирать (разобрал)
# я (я) - рассматривать (рассмотрел)
# я (я) - поставлять (поставил)
# я (мне) - понравиться (понравился)
# автомобиль (чтосреди этих автомобилей) - подходить (подходит не)
# я (я) - перемещаться (переместился)
# я (я) - заставлять (заставлял)
# я (я) - проверять (проверил)
# я (я) - позвонить (позвонил)
#
# ====================================================================================================

# %%
from mapcore.swm.src.components.semnet import Sign
from ScriptExtract.GraphScript.graph_construction import union, get_feature_dict
from collections import OrderedDict

# %%
S = Sign("Script")
actions_script_sign = OrderedDict()
actions_sign = {}
role_sign = {}
obj_sign = {}
signifs = {}

# %%
signifs[S] = S.add_significance()

# %%
import pickle
from ScriptExtract.Preprocessing.TextProcessing import table

table_ = table(use_sem = False).get_table(list_files, test = lambda act: True, name_table = name_table)

# %%
full_list_actions, verb_dict, feature_dict = get_feature_dict(table_)

# %%
actions_script_sign = [Sign("act_%d_%d"%list(verb_dict[key].keys())[0]) for key in verb_dict]
for act_sign in actions_script_sign:
    signifs[act_sign.name] = act_sign.add_significance()
    connector = signifs[act_sign.name].add_feature(signifs[S], zero_out=True)
    S.add_out_significance(connector)

# %%
for act in verb_dict:
    name_act = "act_%d_%d"%list(verb_dict[act].keys())[0]
    if not act in actions_sign:
        act_sign = Sign(act)
        actions_sign[act] = act_sign
        signifs[act] = act_sign.add_significance()
    connector = signifs[act].add_feature(signifs[S], zero_out=True)
    S.add_out_significance(connector)
